# %%
import nltk
file = open('demo.txt').read()
tokens = nltk.word_tokenize(file)
len(tokens)
# Out:
# 397

# %%
tags = nltk.pos_tag(tokens)
tags
# Out:
# [('The', 'DT'),
#  ('environment', 'NN'),
#  ('gives', 'VBZ'),
#  ('us', 'PRP'),
#  ('countless', 'JJ'),
#  ('benefits', 'NNS'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('canâ€™t', 'VBP'),
#  ('repay', 'VB'),
#  ('our', 'PRP$'),
#  ('entire', 'JJ'),
#  ('life', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('connected', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('forest', 'JJS'),
#  (',', ','),
#  ('trees', 'NNS'),
#  (',', ','),
#  ('animals', 'NNS'),
#  (',', ','),
#  ('water', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('air', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('forest', 'JJS'),
#  ('and', 'CC'),
#  ('trees', 'NNS'),
#  ('filter', 'VBP'),
#  ('the', 'DT'),
#  ('air', 'NN'),
#  ('and', 'CC'),
#  ('absorb', 'VB'),
#  ('harmful', 'JJ'),
#  ('gases', 'NNS'),
#  ('.', '.'),
#  ('Plants', 'NNS'),
#  ('purify', 'JJ'),
#  ('water', 'NN'),
#  (',', ','),
#  ('reduce', 'VB'),
#  ('the', 'DT'),
#  ('chances', 'NNS'),
#  ('of', 'IN'),
#  ('flood', 'NN'),
#  ('maintain', 'NN'),
#  ('natural', 'JJ'),
#  ('balance', 'NN'),
#  ('and', 'CC'),
#  ('many', 'JJ'),
#  ('others', 'NNS'),
#  ('.', '.'),
#  ('Moreover', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('environment', 'NN'),
#  ('keeps', 'VBZ'),
#  ('a', 'DT'),
#  ('close', 'JJ'),
#  ('check', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('environment', 'NN'),
#  ('and', 'CC'),
#  ('its', 'PRP$'),
#  ('functioning', 'NN'),
#  (',', ','),
#  ('It', 'PRP'),
#  ('regulates', 'VBZ'),
#  ('the', 'DT'),
#  ('vital', 'JJ'),
#  ('systems', 'NNS'),
#  ('that', 'WDT'),
#  ('are', 'VBP'),
#  ('essential', 'JJ'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('ecosystem', 'NN'),
#  ('.', '.'),
#  ('Besides', 'IN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('maintains', 'VBZ'),
#  ('the', 'DT'),
#  ('culture', 'NN'),
#  ('and', 'CC'),
#  ('quality', 'NN'),
#  ('of', 'IN'),
#  ('life', 'NN'),
#  ('on', 'IN'),
#  ('earth', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('environment', 'NN'),
#  ('regulates', 'VBZ'),
#  ('various', 'JJ'),
#  ('natural', 'JJ'),
#  ('cycles', 'NNS'),
#  ('that', 'WDT'),
#  ('happen', 'VBP'),
#  ('daily', 'RB'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('cycles', 'NNS'),
#  ('help', 'VBP'),
#  ('in', 'IN'),
#  ('maintaining', 'VBG'),
#  ('the', 'DT'),
#  ('natural', 'JJ'),
#  ('balance', 'NN'),
#  ('between', 'IN'),
#  ('living', 'VBG'),
#  ('things', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('environment', 'NN'),
#  ('.', '.'),
#  ('Disturbance', 'NN'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('things', 'NNS'),
#  ('can', 'MD'),
#  ('ultimately', 'RB'),
#  ('affect', 'VB'),
#  ('the', 'DT'),
#  ('life', 'NN'),
#  ('cycle', 'NN'),
#  ('of', 'IN'),
#  ('humans', 'NNS'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('living', 'NN'),
#  ('beings', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('environment', 'NN'),
#  ('has', 'VBZ'),
#  ('helped', 'VBN'),
#  ('us', 'PRP'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('living', 'NN'),
#  ('beings', 'NNS'),
#  ('to', 'TO'),
#  ('flourish', 'VB'),
#  ('and', 'CC'),
#  ('grow', 'VB'),
#  ('from', 'IN'),
#  ('thousands', 'NNS'),
#  ('of', 'IN'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('environment', 'NN'),
#  ('provides', 'VBZ'),
#  ('us', 'PRP'),
#  ('fertile', 'JJ'),
#  ('land', 'NN'),
#  (',', ','),
#  ('water', 'NN'),
#  (',', ','),
#  ('air', 'NN'),
#  (',', ','),
#  ('livestock', 'NN'),
#  ('and', 'CC'),
#  ('many', 'JJ'),
#  ('essential', 'JJ'),
#  ('things', 'NNS'),
#  ('for', 'IN'),
#  ('survival', 'NN'),
#  ('.', '.'),
#  ('Cause', 'NN'),
#  ('of', 'IN'),
#  ('Environmental', 'NNP'),
#  ('Degradation', 'NNP'),
#  ('Human', 'NNP'),
#  ('activities', 'NNS'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('major', 'JJ'),
#  ('cause', 'NN'),
#  ('of', 'IN'),
#  ('environmental', 'JJ'),
#  ('degradation', 'NN'),
#  ('because', 'IN'),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('activities', 'NNS'),
#  ('humans', 'NNS'),
#  ('do', 'VBP'),
#  ('harm', 'VB'),
#  ('the', 'DT'),
#  ('environment', 'NN'),
#  ('in', 'IN'),
#  ('some', 'DT'),
#  ('way', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('activities', 'NNS'),
#  ('of', 'IN'),
#  ('humans', 'NNS'),
#  ('that', 'WDT'),
#  ('causes', 'VBZ'),
#  ('environmental', 'JJ'),
#  ('degradation', 'NN'),
#  ('is', 'VBZ'),
#  ('pollution', 'NN'),
#  (',', ','),
#  ('defective', 'JJ'),
#  ('environmental', 'JJ'),
#  ('policies', 'NNS'),
#  (',', ','),
#  ('chemicals', 'NNS'),
#  (',', ','),
#  ('greenhouse', 'NN'),
#  ('gases', 'NNS'),
#  (',', ','),
#  ('global', 'JJ'),
#  ('warming', 'NN'),
#  (',', ','),
#  ('ozone', 'NN'),
#  ('depletion', 'NN'),
#  (',', ','),
#  ('etc', 'FW'),
#  ('.', '.'),
#  ('All', 'PDT'),
#  ('these', 'DT'),
#  ('affect', 'VBP'),
#  ('the', 'DT'),
#  ('environment', 'NN'),
#  ('badly', 'RB'),
#  ('.', '.'),
#  ('Besides', 'IN'),
#  (',', ','),
#  ('these', 'DT'),
#  ('the', 'DT'),
#  ('overuse', 'NN'),
#  ('of', 'IN'),
#  ('natural', 'JJ'),
#  ('resources', 'NNS'),
#  ('will', 'MD'),
#  ('create', 'VB'),
#  ('a', 'DT'),
#  ('situation', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('future', 'NN'),
#  ('there', 'EX'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('no', 'DT'),
#  ('resources', 'NNS'),
#  ('for', 'IN'),
#  ('consumption', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('basic', 'JJ'),
#  ('necessity', 'NN'),
#  ('of', 'IN'),
#  ('living', 'VBG'),
#  ('air', 'NN'),
#  ('will', 'MD'),
#  ('get', 'VB'),
#  ('so', 'RB'),
#  ('polluted', 'JJ'),
#  ('that', 'IN'),
#  ('humans', 'NNS'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('use', 'VB'),
#  ('bottled', 'JJ'),
#  ('oxygen', 'NN'),
#  ('for', 'IN'),
#  ('breathing', 'VBG'),
#  ('.', '.'),
#  ('Above', 'IN'),
#  ('all', 'DT'),
#  (',', ','),
#  ('increasing', 'VBG'),
#  ('human', 'JJ'),
#  ('activity', 'NN'),
#  ('is', 'VBZ'),
#  ('exerting', 'VBG'),
#  ('more', 'RBR'),
#  ('pressure', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('surface', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('earth', 'NN'),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('causing', 'VBG'),
#  ('many', 'JJ'),
#  ('disasters', 'NNS'),
#  ('in', 'IN'),
#  ('an', 'DT'),
#  ('unnatural', 'JJ'),
#  ('form', 'NN'),
#  ('.', '.'),
#  ('Also', 'RB'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('are', 'VBP'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('natural', 'JJ'),
#  ('resources', 'NNS'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('pace', 'NN'),
#  ('that', 'WDT'),
#  ('within', 'IN'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('years', 'NNS'),
#  ('they', 'PRP'),
#  ('will', 'MD'),
#  ('vanish', 'VB'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('earth', 'NN'),
#  ('.', '.'),
#  ('To', 'TO'),
#  ('conclude', 'VB'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('can', 'MD'),
#  ('say', 'VB'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('environment', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('keeping', 'VBG'),
#  ('us', 'PRP'),
#  ('alive', 'JJ'),
#  ('.', '.'),
#  ('Without', 'IN'),
#  ('the', 'DT'),
#  ('blanket', 'NN'),
#  ('of', 'IN'),
#  ('environment', 'NN'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('wonâ€™t', 'VBP'),
#  ('be', 'VB'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('survive', 'VB'),
#  ('.', '.'),
#  ('Moreover', 'RB'),
#  (',', ','),
#  ('the', 'DT'),
#  ('environmentâ€™s', 'JJ'),
#  ('contribution', 'NN'),
#  ('to', 'TO'),
#  ('life', 'NN'),
#  ('can', 'MD'),
#  ('not', 'RB'),
#  ('be', 'VB'),
#  ('repaid', 'VBN'),
#  ('.', '.'),
#  ('Besides', 'IN'),
#  (',', ','),
#  ('still', 'RB'),
#  ('what', 'WP'),
#  ('the', 'DT'),
#  ('environment', 'NN'),
#  ('has', 'VBZ'),
#  ('done', 'VBN'),
#  ('for', 'IN'),
#  ('us', 'PRP'),
#  (',', ','),
#  ('in', 'IN'),
#  ('return', 'NN'),
#  ('we', 'PRP'),
#  ('only', 'RB'),
#  ('have', 'VBP'),
#  ('damaged', 'VBN'),
#  ('and', 'CC'),
#  ('degraded', 'VBD'),
#  ('it', 'PRP'),
#  ('.', '.')]

# %%
from nltk.corpus import stopwords
stop_words = list(stopwords.words('english'))
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
tokens = [ i for i in tokens if not i.lower() in stop_words]
len(tokens)
# Out:
# 243

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
tokens = [ps.stem(i) for i in tokens]
tokens
# Out:
# ['environ',
#  'give',
#  'us',
#  'countless',
#  'benefit',
#  'canâ€™t',
#  'repay',
#  'entir',
#  'life',
#  '.',
#  'connect',
#  'forest',
#  ',',
#  'tree',
#  ',',
#  'anim',
#  ',',
#  'water',
#  ',',
#  'air',
#  '.',
#  'forest',
#  'tree',
#  'filter',
#  'air',
#  'absorb',
#  'harm',
#  'gase',
#  '.',
#  'plant',
#  'purifi',
#  'water',
#  ',',
#  'reduc',
#  'chanc',
#  'flood',
#  'maintain',
#  'natur',
#  'balanc',
#  'mani',
#  'other',
#  '.',
#  'moreov',
#  ',',
#  'environ',
#  'keep',
#  'close',
#  'check',
#  'environ',
#  'function',
#  ',',
#  'regul',
#  'vital',
#  'system',
#  'essenti',
#  'ecosystem',
#  '.',
#  'besid',
#  ',',
#  'maintain',
#  'cultur',
#  'qualiti',
#  'life',
#  'earth',
#  '.',
#  'environ',
#  'regul',
#  'variou',
#  'natur',
#  'cycl',
#  'happen',
#  'daili',
#  '.',
#  'cycl',
#  'help',
#  'maintain',
#  'natur',
#  'balanc',
#  'live',
#  'thing',
#  'environ',
#  '.',
#  'disturb',
#  'thing',
#  'ultim',
#  'affect',
#  'life',
#  'cycl',
#  'human',
#  'live',
#  'be',
#  '.',
#  'environ',
#  'help',
#  'us',
#  'live',
#  'be',
#  'flourish',
#  'grow',
#  'thousand',
#  'year',
#  '.',
#  'environ',
#  'provid',
#  'us',
#  'fertil',
#  'land',
#  ',',
#  'water',
#  ',',
#  'air',
#  ',',
#  'livestock',
#  'mani',
#  'essenti',
#  'thing',
#  'surviv',
#  '.',
#  'caus',
#  'environment',
#  'degrad',
#  'human',
#  'activ',
#  'major',
#  'caus',
#  'environment',
#  'degrad',
#  'activ',
#  'human',
#  'harm',
#  'environ',
#  'way',
#  '.',
#  'activ',
#  'human',
#  'caus',
#  'environment',
#  'degrad',
#  'pollut',
#  ',',
#  'defect',
#  'environment',
#  'polici',
#  ',',
#  'chemic',
#  ',',
#  'greenhous',
#  'gase',
#  ',',
#  'global',
#  'warm',
#  ',',
#  'ozon',
#  'deplet',
#  ',',
#  'etc',
#  '.',
#  'affect',
#  'environ',
#  'badli',
#  '.',
#  'besid',
#  ',',
#  'overus',
#  'natur',
#  'resourc',
#  'creat',
#  'situat',
#  'futur',
#  'resourc',
#  'consumpt',
#  '.',
#  'basic',
#  'necess',
#  'live',
#  'air',
#  'get',
#  'pollut',
#  'human',
#  'use',
#  'bottl',
#  'oxygen',
#  'breath',
#  '.',
#  ',',
#  'increas',
#  'human',
#  'activ',
#  'exert',
#  'pressur',
#  'surfac',
#  'earth',
#  'caus',
#  'mani',
#  'disast',
#  'unnatur',
#  'form',
#  '.',
#  'also',
#  ',',
#  'use',
#  'natur',
#  'resourc',
#  'pace',
#  'within',
#  'year',
#  'vanish',
#  'earth',
#  '.',
#  'conclud',
#  ',',
#  'say',
#  'environ',
#  'keep',
#  'us',
#  'aliv',
#  '.',
#  'without',
#  'blanket',
#  'environ',
#  ',',
#  'wonâ€™t',
#  'abl',
#  'surviv',
#  '.',
#  'moreov',
#  ',',
#  'environmentâ€™',
#  'contribut',
#  'life',
#  'repaid',
#  '.',
#  'besid',
#  ',',
#  'still',
#  'environ',
#  'done',
#  'us',
#  ',',
#  'return',
#  'damag',
#  'degrad',
#  '.']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
tokens = [lemmatizer.lemmatize(i) for i in tokens]
tokens
# Out:
# ['environ',
#  'give',
#  'u',
#  'countless',
#  'benefit',
#  'canâ€™t',
#  'repay',
#  'entir',
#  'life',
#  '.',
#  'connect',
#  'forest',
#  ',',
#  'tree',
#  ',',
#  'anim',
#  ',',
#  'water',
#  ',',
#  'air',
#  '.',
#  'forest',
#  'tree',
#  'filter',
#  'air',
#  'absorb',
#  'harm',
#  'gase',
#  '.',
#  'plant',
#  'purifi',
#  'water',
#  ',',
#  'reduc',
#  'chanc',
#  'flood',
#  'maintain',
#  'natur',
#  'balanc',
#  'mani',
#  'other',
#  '.',
#  'moreov',
#  ',',
#  'environ',
#  'keep',
#  'close',
#  'check',
#  'environ',
#  'function',
#  ',',
#  'regul',
#  'vital',
#  'system',
#  'essenti',
#  'ecosystem',
#  '.',
#  'besid',
#  ',',
#  'maintain',
#  'cultur',
#  'qualiti',
#  'life',
#  'earth',
#  '.',
#  'environ',
#  'regul',
#  'variou',
#  'natur',
#  'cycl',
#  'happen',
#  'daili',
#  '.',
#  'cycl',
#  'help',
#  'maintain',
#  'natur',
#  'balanc',
#  'live',
#  'thing',
#  'environ',
#  '.',
#  'disturb',
#  'thing',
#  'ultim',
#  'affect',
#  'life',
#  'cycl',
#  'human',
#  'live',
#  'be',
#  '.',
#  'environ',
#  'help',
#  'u',
#  'live',
#  'be',
#  'flourish',
#  'grow',
#  'thousand',
#  'year',
#  '.',
#  'environ',
#  'provid',
#  'u',
#  'fertil',
#  'land',
#  ',',
#  'water',
#  ',',
#  'air',
#  ',',
#  'livestock',
#  'mani',
#  'essenti',
#  'thing',
#  'surviv',
#  '.',
#  'caus',
#  'environment',
#  'degrad',
#  'human',
#  'activ',
#  'major',
#  'caus',
#  'environment',
#  'degrad',
#  'activ',
#  'human',
#  'harm',
#  'environ',
#  'way',
#  '.',
#  'activ',
#  'human',
#  'caus',
#  'environment',
#  'degrad',
#  'pollut',
#  ',',
#  'defect',
#  'environment',
#  'polici',
#  ',',
#  'chemic',
#  ',',
#  'greenhous',
#  'gase',
#  ',',
#  'global',
#  'warm',
#  ',',
#  'ozon',
#  'deplet',
#  ',',
#  'etc',
#  '.',
#  'affect',
#  'environ',
#  'badli',
#  '.',
#  'besid',
#  ',',
#  'overus',
#  'natur',
#  'resourc',
#  'creat',
#  'situat',
#  'futur',
#  'resourc',
#  'consumpt',
#  '.',
#  'basic',
#  'necess',
#  'live',
#  'air',
#  'get',
#  'pollut',
#  'human',
#  'use',
#  'bottl',
#  'oxygen',
#  'breath',
#  '.',
#  ',',
#  'increas',
#  'human',
#  'activ',
#  'exert',
#  'pressur',
#  'surfac',
#  'earth',
#  'caus',
#  'mani',
#  'disast',
#  'unnatur',
#  'form',
#  '.',
#  'also',
#  ',',
#  'use',
#  'natur',
#  'resourc',
#  'pace',
#  'within',
#  'year',
#  'vanish',
#  'earth',
#  '.',
#  'conclud',
#  ',',
#  'say',
#  'environ',
#  'keep',
#  'u',
#  'aliv',
#  '.',
#  'without',
#  'blanket',
#  'environ',
#  ',',
#  'wonâ€™t',
#  'abl',
#  'surviv',
#  '.',
#  'moreov',
#  ',',
#  'environmentâ€™',
#  'contribut',
#  'life',
#  'repaid',
#  '.',
#  'besid',
#  ',',
#  'still',
#  'environ',
#  'done',
#  'u',
#  ',',
#  'return',
#  'damag',
#  'degrad',
#  '.']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

result = tfidf.fit_transform(tokens)

for ele1, ele2 in zip(tfidf.get_feature_names(), tfidf.idf_):
    print(ele1, ':', ele2)
# Out:
# abl : 5.804021044733257
# absorb : 5.804021044733257
# activ : 4.887730312859102
# affect : 5.398555936625092
# air : 4.887730312859102
# aliv : 5.804021044733257
# also : 5.804021044733257
# anim : 5.804021044733257
# badli : 5.804021044733257
# balanc : 5.398555936625092
# basic : 5.804021044733257
# be : 5.398555936625092
# benefit : 5.804021044733257
# besid : 5.110873864173311
# blanket : 5.804021044733257
# bottl : 5.804021044733257
# breath : 5.804021044733257
# canâ : 5.804021044733257
# caus : 4.887730312859102
# chanc : 5.804021044733257
# check : 5.804021044733257
# chemic : 5.804021044733257
# close : 5.804021044733257
# conclud : 5.804021044733257
# connect : 5.804021044733257
# consumpt : 5.804021044733257
# contribut : 5.804021044733257
# countless : 5.804021044733257
# creat : 5.804021044733257
# cultur : 5.804021044733257
# cycl : 5.110873864173311
# daili : 5.804021044733257
# damag : 5.804021044733257
# defect : 5.804021044733257
# degrad : 4.887730312859102
# deplet : 5.804021044733257
# disast : 5.804021044733257
# disturb : 5.804021044733257
# done : 5.804021044733257
# earth : 5.110873864173311
# ecosystem : 5.804021044733257
# entir : 5.804021044733257
# environ : 3.932218867831665
# environment : 4.887730312859102
# environmentâ : 5.804021044733257
# essenti : 5.398555936625092
# etc : 5.804021044733257
# exert : 5.804021044733257
# fertil : 5.804021044733257
# filter : 5.804021044733257
# flood : 5.804021044733257
# flourish : 5.804021044733257
# forest : 5.398555936625092
# form : 5.804021044733257
# function : 5.804021044733257
# futur : 5.804021044733257
# gase : 5.398555936625092
# get : 5.804021044733257
# give : 5.804021044733257
# global : 5.804021044733257
# greenhous : 5.804021044733257
# grow : 5.804021044733257
# happen : 5.804021044733257
# harm : 5.398555936625092
# help : 5.398555936625092
# human : 4.551258076237889
# increas : 5.804021044733257
# keep : 5.398555936625092
# land : 5.804021044733257
# life : 4.887730312859102
# live : 4.887730312859102
# livestock : 5.804021044733257
# maintain : 5.110873864173311
# major : 5.804021044733257
# mani : 5.110873864173311
# moreov : 5.398555936625092
# natur : 4.705408756065147
# necess : 5.804021044733257
# other : 5.804021044733257
# overus : 5.804021044733257
# oxygen : 5.804021044733257
# ozon : 5.804021044733257
# pace : 5.804021044733257
# plant : 5.804021044733257
# polici : 5.804021044733257
# pollut : 5.398555936625092
# pressur : 5.804021044733257
# provid : 5.804021044733257
# purifi : 5.804021044733257
# qualiti : 5.804021044733257
# reduc : 5.804021044733257
# regul : 5.398555936625092
# repaid : 5.804021044733257
# repay : 5.804021044733257
# resourc : 5.110873864173311
# return : 5.804021044733257
# say : 5.804021044733257
# situat : 5.804021044733257
# still : 5.804021044733257
# surfac : 5.804021044733257
# surviv : 5.398555936625092
# system : 5.804021044733257
# thing : 5.110873864173311
# thousand : 5.804021044733257
# tree : 5.398555936625092
# ultim : 5.804021044733257
# unnatur : 5.804021044733257
# use : 5.398555936625092
# vanish : 5.804021044733257
# variou : 5.804021044733257
# vital : 5.804021044733257
# warm : 5.804021044733257
# water : 5.110873864173311
# way : 5.804021044733257
# within : 5.804021044733257
# without : 5.804021044733257
# wonâ : 5.804021044733257
# year : 5.398555936625092
