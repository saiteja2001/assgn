# %% [markdown]
# ## dataset link - https://www.kaggle.com/datasets/aljarah/xAPI-Edu-Data

# %%
import pandas as pd
ds = pd.read_csv("academic_performance.csv")

# %%
ds
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
for i in list(ds.columns):
    print(i)
    boolean = pd.isnull(ds[i])
    if len(ds[boolean])==0:
        print("No empty values")
        print(ds[i].value_counts())
    else:
        print(ds[boolean])
    print('----------------------------------------------------')
# Out:
# gender
# No empty values
# M    305
# F    175
# Name: gender, dtype: int64
# ----------------------------------------------------
# NationalITy
# No empty values
# KW             179
# Jordan         172
# Palestine       28
# Iraq            22
# lebanon         17
# Tunis           12
# SaudiArabia     11
# Egypt            9
# Syria            7
# USA              6
# Iran             6
# Lybia            6
# Morocco          4
# venzuela         1
# Name: NationalITy, dtype: int64
# ----------------------------------------------------
# PlaceofBirth
# No empty values
# KuwaIT         180
# Jordan         176
# Iraq            22
# lebanon         19
# SaudiArabia     16
# USA             16
# Palestine       10
# Egypt            9
# Tunis            9
# Iran             6
# Syria            6
# Lybia            6
# Morocco          4
# venzuela         1
# Name: PlaceofBirth, dtype: int64
# ----------------------------------------------------
# StageID
# No empty values
# ...

# %%
def grade_convert(x):
    if x=="F":
        return 1
    else:
        return 2
        

ds['Semester']=ds['Semester'].apply(grade_convert)

# %%
def satisfaction(x):
    if x=='Good':
        return 1
    else:
        return -1
    
ds['ParentschoolSatisfaction']=ds['ParentschoolSatisfaction'].apply(satisfaction)

# %%
absent_days = list(ds['StudentAbsenceDays'].unique())
def absent(x):
    return absent_days.index(x)
ds['StudentAbsenceDays']=ds['StudentAbsenceDays'].apply(absent)

# %%
def survey(x):
    if x=='Yes':
        return 1
    else:
        return 0
    
ds['ParentAnsweringSurvey']=ds['ParentAnsweringSurvey'].apply(survey)

# %%
int(ds['Discussion'].mean())
# Out:
# 43

# %%
dis_avg=int(ds['Discussion'].mean())
def discussion(x):
    if x<15:
        return dis_avg
    else:
        return x
    
ds['Discussion']=ds['Discussion'].apply(discussion)

# %%
int(ds['VisITedResources'].mean())
# Out:
# 54

# %%
vis_avg=int(ds['VisITedResources'].mean())
def visited_resource(x):
    if x<20:
        return vis_avg
    else:
        return x
    
ds['VisITedResources']=ds['VisITedResources'].apply(visited_resource)

# %%
int(ds['AnnouncementsView'].mean())
# Out:
# 37

# %%
ann_avg=int(ds['AnnouncementsView'].mean())
def ann_view(x):
    if x<5:
        return ann_avg
    else:
        return x
    
ds['AnnouncementsView']=ds['AnnouncementsView'].apply(ann_view)

# %%
def grade_convert(x):
    y=0
    x=x[::-1]
    for i in range(len(x)):
        if x[i]!='-':
            y+=(int(x[i])*(10**i))
        else:
            break
    return y
        

ds['GradeID']=ds['GradeID'].apply(grade_convert)

# %%
ds
# Out:
#     gender NationalITy PlaceofBirth       StageID  GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel        4         A
# 1        M          KW       KuwaIT    lowerlevel        4         A
# 2        M          KW       KuwaIT    lowerlevel        4         A
# 3        M          KW       KuwaIT    lowerlevel        4         A
# 4        M          KW       KuwaIT    lowerlevel        4         A
# ..     ...         ...          ...           ...      ...       ...
# 475      F      Jordan       Jordan  MiddleSchool        8         A
# 476      F      Jordan       Jordan  MiddleSchool        8         A
# 477      F      Jordan       Jordan  MiddleSchool        8         A
# 478      F      Jordan       Jordan  MiddleSchool        8         A
# 479      F      Jordan       Jordan  MiddleSchool        8         A
#
#          Topic  Semester Relation  raisedhands  VisITedResources  \
# 0           IT         1   Father           15                54
# ...
